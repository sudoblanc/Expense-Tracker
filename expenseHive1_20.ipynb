# %%
# -*- coding: utf-8 -*-
"""expensehive.ipynb

Automatically generated by Colaboratory.

Original file is located at
    https://colab.research.google.com/gist/sudoblanc/2cef37982b1086e39c2786a8707281ce/expensehive.ipynb
"""
import matplotlib.pyplot as plt

expenses = []
user_expense_cost = []
user_expense_dates = []


#function section starts
def main_menu():
    print("*------------------------------*")
    print("   WELCOME TO EXPENSE HIVE      ")
    print("Choose one of the task that you would like to do: ")
    print("Enter 1. Enter Expense")
    print("Enter 2. Display saved expenses")
    print("Enter 3. Expense chart")
    print("Enter 4. Exit")
    user_choice = int(input("Enter you choice(1 or 2 or 3 or 4):"))
    return user_choice

def user_pref():
    print("Do you want to Perform other tasks ?")
    print("Enter Y to Return to the MAIN MENU")
    print("Entet Q ro quit using ExpenseHive.") 
    user_preference = str(input('Enter your choice: '))
      
def user_exit():
    exit_prompt = print('*-----Thanks for using ExpenseHive-----*')
    return exit_prompt
    quit()
def user_saved_expenses():
    print(expenses)
    print(user_expense_cost)
    print(user_expense_dates)
def saving_data():
    expenses.append(expense_name)
    user_expense_cost.append(expense_cost)
    user_expense_dates.append(expense_date)
def total_expense():
    user_total = sum(user_expense_cost)
    print("Your total expense is", user_total)
    return user_total
def budget_reminder():
    sum_total = total_expense()
    diff = float(user_budget) - float(sum_total)
    if len(expenses) == 0:
      print("No budget assugned yet")
    else:
      print("You have",diff,"left to spend")          
    
    #make a promp to declare a monthly budget and create a graph as you enter

#function section ends

#firstchoice starts
user_preference = 'Y' #loop to assume if true then run the program again
while user_preference == 'Y':
    user_choice = main_menu()
    if user_choice == 1:

        user_budget = float(input('Enter your todays budget: '))
        if user_budget == 0:
          print("You have not entered your budget yet")
        else:
          total_expense()


  
        expense_name = str(input('Expense Name: '))   
        expense_cost = float(input('Expense Cost: '))
        expense_date = str(input('Expense Date(mm/dd/yy): '))
      
        #prompt to make decisions to save or not
        save_expense = str(input("Do you want to save the expense ?(y/n): "))
        if save_expense.casefold() == 'y':
            print("Your expense has been saved")
            saving_data()
            user_pref()
        elif save_expense.casefold() == 'n':
            print("Expense has not been saved")
            user_pref()
        else:
            print("Wrong Input (ERROR)")
            user_pref()
        #end of prompt to make decisions to save or not
        

        #end of userchoice prompt        
#end of first choice

#second choice starts

    elif user_choice == 2:
        print("Here is your list of expenses")
        #use this section to return saved files before 
        print(expenses)
        print(user_expense_cost)
        print(user_expense_dates)
        if len(expenses) == 0:
          print("No budget assigned yet")
        else:  
          total_expense()
          print("your budget for the day is:",user_budget)
          budget_reminder()

        
        #if diff < user_budget:
          #print('You have',diff,'more to spend!')
        #elif diff == 0:
          #print("You have reached your budget limit please stop spending.")
       # else:
          #print('Seems like we have a problem with the data please prompt again')
        #total_expense()

#end of second choice

#third choice starts
    elif user_choice == 3:
        print("Here is your expense chart")
        #if user_budget =< 300:

            # make a matplotlib bargraph to represent the type of expense that you spent on
            #dev_x = [25, 26, 27, 28, 29]  # could use date to see the number of expense did on that day
            #dev_y = [0, 50, 100, 200, 300]
            # could be used as an empty list to create
            #plt.plot(dev_x, dev_y)
            #plt.show()
        #elif user_budget <= 50:
        #dev_x = [25, 26, 27, 28, 29]
        #dev_y = [0, 15, 30, 45, 50]
        dev_x = expenses
        dev_y = user_expense_cost
        plt.plot(dev_x,dev_y)
        plt.xlabel('Expenses')
        plt.ylabel('Daily Expense Chart')
        plt.show()
        user_pref()
#end of third choice

    elif user_choice == 4:
        user_exit()
    else:
        print('Please input the options in number shown below:')
        user_pref()




#file with panda data that stores the data that user stored with command Y/n or
#some commands
# Out:
# *------------------------------*
#    WELCOME TO EXPENSE HIVE
# Choose one of the task that you would like to do:
# Enter 1. Enter Expense
# Enter 2. Display saved expenses
# Enter 3. Expense chart
# Enter 4. Exit
# Your total expense is 0
# Your expense has been saved
# Do you want to Perform other tasks ?
# Enter Y to Return to the MAIN MENU
# Entet Q ro quit using ExpenseHive.
# *------------------------------*
#    WELCOME TO EXPENSE HIVE
# Choose one of the task that you would like to do:
# Enter 1. Enter Expense
# Enter 2. Display saved expenses
# Enter 3. Expense chart
# Enter 4. Exit
# Here is your list of expenses
# ['GORC']
# [25.5]
# ['12/22/2022']
# Your total expense is 25.5
# your budget for the day is: 50.0
# Your total expense is 25.5
# You have 24.5 left to spend
# *------------------------------*
#    WELCOME TO EXPENSE HIVE
# Choose one of the task that you would like to do:
# Enter 1. Enter Expense
# Enter 2. Display saved expenses
# Enter 3. Expense chart
# ...

# %%
#notes
# user name and data matching
# deleting an expense
#add a loop to prompt user to input expense multiple times
#if user wants to add 3 expenses make 3 rows 3 coloumns
